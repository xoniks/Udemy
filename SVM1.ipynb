# %% [markdown]
# <a href="https://colab.research.google.com/github/xoniks/Udemy/blob/master/SVM1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url='https://raw.githubusercontent.com/xoniks/Udemy/master/Udemy_1/Complete%20linear%20regression%20analysis%20in%20python/Customer.csv'
data1=pd.read_csv(url,header=0,index_col=0)
data1.head()
# Out:
#                Customer Name    Segment  ...  Postal Code Region
# Customer ID                              ...
# CG-12520         Claire Gute   Consumer  ...        42420  South
# DV-13045     Darrin Van Huff  Corporate  ...        90036   West
# SO-20335      Sean O'Donnell   Consumer  ...        33311  South
# BH-11710     Brosina Hoffman   Consumer  ...        90032   West
# AA-10480        Andrew Allen   Consumer  ...        28027  South
#
# [5 rows x 8 columns]

# %%
data1.describe()
# Out:
#               Age   Postal Code
# count  793.000000    793.000000
# mean    44.467844  55229.717528
# std     15.526673  31679.223816
# min     18.000000   1841.000000
# 25%     31.000000  27217.000000
# 50%     45.000000  55901.000000
# 75%     58.000000  90004.000000
# max     70.000000  99207.000000

# %%
data1.iloc[0]
# Out:
# Customer Name      Claire Gute
# Segment               Consumer
# Age                         67
# Country          United States
# City                 Henderson
# State                 Kentucky
# Postal Code              42420
# Region                   South
# Name: CG-12520, dtype: object

# %%
data1.iloc[0:14:2]#show each second row
# Out:
#                Customer Name      Segment  ...  Postal Code   Region
# Customer ID                                ...
# CG-12520         Claire Gute     Consumer  ...        42420    South
# SO-20335      Sean O'Donnell     Consumer  ...        33311    South
# AA-10480        Andrew Allen     Consumer  ...        28027    South
# HP-14815       Harold Pawlan  Home Office  ...        76106  Central
# AG-10270     Alejandro Grove     Consumer  ...        84084     West
# KB-16585           Ken Black    Corporate  ...        68025  Central
# EB-13870         Emily Burns     Consumer  ...        84057     West
#
# [7 rows x 8 columns]

# %% [markdown]
# #Seaborn

# %%
import seaborn as sns
sns.displot(data1)
sns.displot(data1.Age, kde= True)

# %%
iris = sns.load_dataset('iris')
iris.head()
print(iris.shape) 
iris.describe()
# Out:
# (150, 5)
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris)

# %%
sns.pairplot(iris)
